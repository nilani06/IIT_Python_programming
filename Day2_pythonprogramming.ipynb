# %% [markdown]
# # Python Programming

# %% [markdown]
# ### Day 2

# %%
myName="Lucy" #camelCase
_age=19
# can start with underscore but not numbers and cannot use keywords for variable names
height=5.7

# %%
print(myName)
print(_age)
print(height)
# Out:
# Lucy
# 19
# 5.7

# %%
print(type(myName))
print(type(_age))
print(type(height))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
full_name=input("What is your name?: ") #snake_case
print(full_name)
# Out:
# What is your name?:  Lucy April
# Lucy April

# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ### Question 1

# %%
pet_name=input('what is the name of your pet?: ')
home_town=input('what is your home town?: ')
dream_job=input('what is your dream job?: ')
print(type(pet_name))
print(type(home_town))
print(type(dream_job))
# Out:
# what is the name of your pet?:  Momo
# what is your home town?:  London
# what is your dream job?:  Data Scientist
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# ### Question 2

# %%
year_born=int(input('what is your birth year?: '))
print(type(year_born))
# Out:
# what is your birth year?:  2006
# <class 'int'>

# %% [markdown]
# ### Question 3

# %%
has_subsciption=bool(input('are you currently a member?: '))
print(type(has_subsciption))
# Out:
# are you currently a member?:  True
# <class 'bool'>

# %% [markdown]
# ### Question 4

# %%
coffee_price=float(input('what is the price of the coffee?: '))
print(type(coffee_price))
# Out:
# what is the price of the coffee?:  3.50
# <class 'float'>

# %% [markdown]
# ### Question 5

# %%
item_name=input('what is the name of the item?: ')
quantity_available=int(input('how much quantity is available?: '))
print(type(item_name))
print(type(quantity_available))
# Out:
# what is the name of the item?:  coffee
# how much quantity is available?:  20
# <class 'str'>
# <class 'int'>

# %% [markdown]
# ### Numerical Operators

# %%
10+5 #addtion
# Out:
# 15

# %%
10-5 #substraction
# Out:
# 5

# %%
7//2 #division only whole number
# Out:
# 3

# %%
7/2 #divison
# Out:
# 3.5

# %%
3*5 #multiplication
# Out:
# 15

# %%
3**3 #power
# Out:
# 27

# %%
8%3 # modulus
# Out:
# 2

# %%
a="Lucy "
b="April"
a += b
print(a)
# Out:
# Lucy April

# %%
c=20
d=10
c+=d
print(c)
# Out:
# 30

# %%
c=20
d=10
c-=d
print(c)
# Out:
# 10

# %%
c=20
d=10
c*=d
print(c)
# Out:
# 200

# %%
c=20
d=10
c/=d
print(c)
# Out:
# 2.0

# %%
c=20
d=10
c//=d
print(c)
# Out:
# 2

# %%
c=20
d=10
c%=d
print(c)
# Out:
# 0

# %%
c=20
d=10
c**=d
print(c)
# Out:
# 10240000000000

# %% [markdown]
# ### Comparison operators

# %%
a == b # equal to
a != b # not equal to
a > b # greater than
a < b # less than
a >= b # greater than or equal
a <= b # less than or equal

# %% [markdown]
# ### Logical operators

# %%
and # AND means multiplication
or # OR means addition
not # opposite
