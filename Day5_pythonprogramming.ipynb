# %% [markdown]
# ## Python Programming

# %% [markdown]
# ### Day 5

# %%
# functions
# 3print(), len(), range(), input(), sum(), max(), type(), def

# %%
def calculate():
    print('hello IIT')

# %%
calculate()
calculate()
# Out:
# hello IIT
# hello IIT

# %%
def cal(a, b): # a and b are parameters
    if a>b:
        print(a-b)
    elif a<b:
        print(a+b)
    else:
        print("invalid input try again")

# %%
cal(2,5) # after calling a and b, they are called arguments
cal(9, 4)
# Out:
# 7
# 5

# %%
cal(6,6)
# Out:
# invalid input try again

# %%
def greet(name1):
    print(f" Hello {name1}")

# %%
greet("Nilani")
# Out:
#  Hello Nilani

# %%
def Greet(name1='Guest'):
    print(f" Hello {name1}")

# %%
Greet()
Greet('Nilani')
# Out:
#  Hello Guest
#  Hello Nilani

# %%
def Cal(a, b):
    return a+b

result = Cal(5, 3)
print("sum" ,result)
# Out:
# sum 8

# %%
def Calculate(a, b): # a and b are parameters
    if a>b:
        print(a-b)
    elif a<b:
        print(a+b)
    else:
        print("invalid input try again")
Calculate(2, 4)
# Out:
# 6

# %%
for i in range (1, 11, 1):
    if i==5:
        continue
    print(i)
print('')
for i in range (1, 11, 1):
    if i!=5:
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 10
#
# 5

# %%
def pending():
    pass

# %%
def Addintion(a, b):
    a=int(input("a = "))
    b=int(input("b = "))
    print(a+b)

def Substraction(a, b):
    a=int(input("a = "))
    b=int(input("b = "))
    print(a-b)

def Multiplication(a, b):
    a=int(input("a = "))
    b=int(input("b = "))
    print(a*b)

def Division(a, b):
    a=int(input("a = "))
    b=int(input("b = "))
    if b==0:
        print("ERROR")
    else:
        print(a/b)


def calculator(): 
    print("*** Calculator ***")
    print("MENU")
    print("1. Addition")
    print("2. Substraction")
    print("3. Multiplication")
    print("4. Division")
    print("5. exit")
    Function=input("Enter the correct function")
    if Function=="1":
        Addition(1, 1)
    elif Function=="2":
        Substraction(1, 1)
    elif Function=="3":
         Multiplication(1, 1)
    elif Function=="4":
        Division(1, 1)
    elif Function == "5":
        print("Exit calculator")
    else:
        print("Invalid response")

calculator()
# Out:
# *** Calculator ***
# MENU
# 1. Addition
# 2. Substraction
# 3. Multiplication
# 4. Division
# 5. exit
# Enter the correct function 5
# Exit calculator
