# %% [markdown]
# ##  python programming

# %% [markdown]
# ### day 1

# %%
print("Nilani")
# Out:
# Nilani

# %%
print('hello')
# Out:
# hello

# %% [markdown]
# # level 1 single hash

# %% [markdown]
# ## level 2 double hash

# %% [markdown]
# ### level 3 triple hash

# %%
print("My name is NIlani")
print("I'm a full time student and RIC")
print("pursuing data science and Buisness analytics")
# Out:
# My name is NIlani
# I'm a full time student and RIC
# pursuing data science and Buisness analytics
